# %% [markdown]
# ## understanding dataset to explore how the data is present in the dataset and there is need of creating some aggregate tale than that can help with :
# 1.vendor selection foirb profitability
# 2.product pricing optimiztion

# %%
import pandas as pd
import sqlite3
import os

# %%
# create a connection of database
conn=sqlite3.connect('inventory.db')

# %%
# check the table present inside the database
tables=pd.read_sql_query("select name from sqlite_master where type='table'",conn)
tables
# Out:
#                    name
# 0       begin_inventory
# 1         end_inventory
# 2             purchases
# 3       purchase_prices
# 4                 sales
# 5        vendor_invoice
# 6          vendor_sales
# 7  vendor_sales_summary

# %%
for table in tables['name']:
    print('-'*50,f'{table}','-'*50)
    print('count of records',pd.read_sql(f"select count(*) as count from {table}",conn)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 5",conn))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# count of records 206529
#    False        InventoryId  Store          City  Brand  \
# 0      0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1      1  1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2      2  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3      3  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4      4  1_HARDERSFIELD_72      1  HARDERSFIELD     72
#
#                    Description   Size  onHand  Price   startDate
# 0  Gekkeikan Black & Gold Sake  750mL       8  12.99  2024-01-01
# 1       Canadian Club 1858 VAP  750mL       7  10.99  2024-01-01
# 2     Herradura Silver Tequila  750mL       6  36.99  2024-01-01
# 3   Herradura Reposado Tequila  750mL       3  38.99  2024-01-01
# 4         No. 3 London Dry Gin  750mL       6  34.99  2024-01-01
# ...

# %%
pd.read_sql_query("""select count(VendorName) as names,count(VendorNumber) as nums from purchases group by VendorNumber""",conn)
# Out:
#      names  nums
# 0       13    13
# 1        1     1
# 2      626   626
# 3       57    57
# 4        8     8
# ..     ...   ...
# 121   1509  1509
# 122     41    41
# 123    149   149
# 124    153   153
# 125      1     1
#
# [126 rows x 2 columns]

# %%
sales=pd.read_sql_query("""select * from sales where VendorNo=4466""",conn)

# %%
sales.columns
# Out:
# Index(['False', 'InventoryId', 'Store', 'Brand', 'Description', 'Size',
#        'SalesQuantity', 'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume',
#        'Classification', 'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
sales.groupby('Brand')[['SalesQuantity','SalesDollars']].sum()
# Out:
#        SalesQuantity  SalesDollars
# Brand
# 3140            3890      50531.10
# 5215            4651      60416.49
# 5255            6096      79187.04

# %%
purchases=pd.read_sql_query("""select * from purchases where VendorNumber=4466""",conn)

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
freight_summary=pd.read_sql_query("""select VendorNumber,sum(Freight) as freight_cost from vendor_invoice 
group by VendorNumber""",conn)
freight_summary
# Out:
#      VendorNumber  freight_cost
# 0               2         27.08
# 1              54          0.48
# 2              60        367.52
# 3             105         62.39
# 4             200          6.19
# ..            ...           ...
# 121         98450        856.02
# 122         99166        130.09
# 123        172662        178.34
# 124        173357        202.50
# 125        201359          0.09
#
# [126 rows x 2 columns]

# %%
PurchasesData=pd.read_sql_query("""select p.VendorName,p.VendorNumber,p.Brand,pp.Volume,pp.Price as ActualPrice,p.PurchasePrice,
sum(Quantity) as TotalPurchaseQuantity,
sum(Dollars) as TotalPuchaseDollars from purchases as p join purchase_prices as pp
on p.Brand=pp.Brand 
where p.PurchasePrice>0
group by p.VendorName,p.VendorNumber,p.Brand
order by TotalPuchaseDollars""",conn) 
PurchasesData
# Out:
#                         VendorName  VendorNumber  Brand Volume  ActualPrice  \
# 0      PROXIMO SPIRITS INC.                 7245   3065     50         0.99
# 1      DIAGEO NORTH AMERICA INC             3960   6127    200         1.99
# 2      HEAVEN HILL DISTILLERIES             3924   9123     50         0.99
# 3      SAZERAC CO INC                       8004   5683     50         0.49
# 4      WINE GROUP INC                       9815   8527    750         4.99
# ...                            ...           ...    ...    ...          ...
# 10687  DIAGEO NORTH AMERICA INC             3960   3545   1750        29.99
# 10688  DIAGEO NORTH AMERICA INC             3960   4261   1750        22.99
# 10689  PERNOD RICARD USA                   17035   8068   1750        24.99
# 10690        MARTIGNETTI COMPANIES          4425   3405   1750        28.99
# 10691  BROWN-FORMAN CORP                    1128   1233   1750        36.99
#
# ...

# %%
salesData=pd.read_sql_query("""select VendorNo,Brand,sum(SalesDollars) as ToatlDollars,sum(SalesPrice) as ToatlPrice,
sum(SalesQuantity) as TotalQuantity,
sum(ExciseTax) as TotalTax from sales 
group by VendorNo,Brand""",conn)
salesData
# Out:
#        VendorNo  Brand  ToatlDollars  ToatlPrice  TotalQuantity  TotalTax
# 0             2  90085        665.82      295.92             18      2.00
# 1             2  90609        599.76      449.82             24      0.52
# 2            60    771        704.53      494.67             47     37.01
# 3            60   3979      66871.69    41682.51           3931   7224.06
# 4           105   2529        359.88       59.98             12      9.44
# ...         ...    ...           ...         ...            ...       ...
# 11267    173357   2804       6298.60     3194.29            140    110.33
# 11268    173357   3666       8996.40     4873.05            360    141.19
# 11269    173357   3848        185.94       92.97              6      4.71
# 11270    173357   3909      24540.18    14469.21            982    773.87
# 11271    201359  90609       1474.41     1324.47             59      1.24
#
# [11272 rows x 6 columns]

# %%
vendor_sales_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT
        p.VendorName,
        p.VendorNumber,
        p.Description,
        p.Brand,
        pp.Volume,
        pp.Price AS ActualPrice,
        p.PurchasePrice,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY
        p.VendorName,
        p.VendorNumber,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price,
        pp.Volume
),

SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(ExciseTax) AS TotalTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesPrice,
    ss.TotalTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
   AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC;
""", conn)
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %% [markdown]
# this query genrates a vendorwise sales and summery values for:
# ## performance optimization
# 1.Aggregate first, join later.
# 2.Reduces the number of rows processed during joins.
# 3.Improves SQL query performance and memory efficiency.
# 4.Produces a clean analytical dataset ready for EDA and visualization

# %%
# to check the data is cleaned or not
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesDollars        178
# TotalSalesQuantity       178
# TotalSalesPrice          178
# TotalTax                 178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesDollars        float64
# TotalSalesQuantity       float64
# TotalSalesPrice          float64
# TotalTax                 float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
vendor_sales_summary['Volume']=vendor_sales_summary['Volume'].astype('float64')

# %%
vendor_sales_summary.fillna(0,inplace=True)

# %%
vendor_sales_summary['VendorName'].str.strip()
# Out:
# 0               BROWN-FORMAN CORP
# 1           MARTIGNETTI COMPANIES
# 2               PERNOD RICARD USA
# 3        DIAGEO NORTH AMERICA INC
# 4        DIAGEO NORTH AMERICA INC
#                    ...
# 10687              WINE GROUP INC
# 10688              SAZERAC CO INC
# 10689    HEAVEN HILL DISTILLERIES
# 10690    DIAGEO NORTH AMERICA INC
# 10691        PROXIMO SPIRITS INC.
# Name: VendorName, Length: 10692, dtype: object

# %%
vendor_sales_summary['Gross_profit']=vendor_sales_summary['TotalSalesDollars']-vendor_sales_summary['TotalPurchaseDollars']
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary['Profit_margin']=(vendor_sales_summary['Gross_profit']/vendor_sales_summary['TotalSalesDollars'])*100

# %%
# it define the how much quantity of products are left
vendor_sales_summary['StockTurnOver']=vendor_sales_summary['TotalPurchaseQuantity']/vendor_sales_summary['TotalSalesQuantity']

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'ActualPrice', 'Volume', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesDollars', 'TotalSalesQuantity',
#        'TotalSalesPrice', 'TotalTax', 'FreightCost', 'Gross_profit',
#        'Profit_margin', 'StockTurnOver'],
#       dtype='object')

# %%
cursor=conn.cursor()

# %%
cursor.execute("""create table vendor_sales(
               VendorNumber int,
               VendorName varchar(100),
               Brand int,
               Description varchar(100),
               PurchasePrice decimal(10,2),
               ActualPrice decimal(10,2),
               Volume,
               TotalPurchaseQuantity int,
               TotalPurchaseDollars decimal(15,2),
               TotalSalesDollars decimal(15,2),
               TotalSalesQuantity int,
               TotalSalesPrice decimal(15,2),
               TotalTax decimal(15,2),
               FreightCost decimal(15,2),
               Gross_profit decimal(15,2),
               Profit_margin decimal(15,2),
               StockTurnOver decimal(15,2),
               primary key(VendorNumber,Brand));""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cursor.execute("""create table vendor_sales(
#       2                VendorNumber int,
#       3                VendorName varchar(100),
#       4                Brand int,
#       5                Description varchar(100),
#       6                PurchasePrice decimal(10,2),
#       7                ActualPrice decimal(10,2),
#       8                Volume,
#       9                TotalPurchaseQuantity int,
#      10                TotalPurchaseDollars decimal(15,2),
#      11                TotalSalesDollars decimal(15,2),
#      12                TotalSalesQuantity int,
#      13                TotalSalesPrice decimal(15,2),
#      14                TotalTax decimal(15,2),
#      15                FreightCost decimal(15,2),
#      16                Gross_profit decimal(15,2),
# ...

# %%
pd.read_sql_query("select* from vendor_sales",conn)

# %%
vendor_sales_summery.to_sql('vendor_sales',conn,if_exists='replace',index=False)

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_table import ingest_db

logging.basicConfig(
    filename="logs/get_vendor_summery.py",
    level=logging.DEBUG,
    format="%(asctime)s-%(levelname)s-%(message)s",
    filemode="a"
)

def create_vendor_summery(conn):
    '''this function will merge the differnt tables in one to get the vendor summery and add new columns in resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (SELECT
    VendorNumber,
    SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber),
    PurchaseSummary AS (
    SELECT
        p.VendorName,
        p.VendorNumber,
        p.Description,
        p.Brand,
        pp.Volume,
        pp.Price AS ActualPrice,
        p.PurchasePrice,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
        FROM purchases p
        JOIN purchase_prices pp
        ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY
        p.VendorName,
        p.VendorNumber,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price,
        pp.Volume),
        
        SalesSummary AS (SELECT
        VendorNo,
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(ExciseTax) AS TotalTax
        FROM sales GROUP BY VendorNo, Brand
        )
        
        SELECT 
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseDollars,
        ss.TotalSalesDollars,
        ss.TotalSalesQuantity,
        ss.TotalSalesPrice,
        ss.TotalTax,
        fs.FreightCost
        FROM PurchaseSummary ps
        LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNo AND ps.Brand = ss.Brand
        LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
        ORDER BY ps.TotalPurchaseDollars DESC;""", conn)
    return vendor_sales_summary

def clean_data(df):

    df['Volume'] = df['Volume'].astype(float)

    df.fillna(0, inplace=True)

    df['VendorName'] = df['VendorName'].str.strip()
    df['Description'] = df['Description'].str.strip()

    df['Gross_profit'] = (
        df['TotalSalesDollars'] - df['TotalPurchaseDollars']
    )

    df['Profit_margin'] = (
        df['Gross_profit'] / df['TotalSalesDollars']
    ) * 100

    df['StockTurnOver'] = (
        df['TotalPurchaseQuantity'] / df['TotalSalesQuantity']
    )

    return df

if __name__ == "__main__":
    #creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('creating vendor summery table')
    summery_df = create_vendor_summery(conn)

    logging.info('cleaning the data')
    clean_df = clean_data(summery_df)

    logging.info('create an ingesting data')
    ingest_db(clean_df, 'vendor_sales_summary', conn)

    logging.info('completed')

# %%
vendor_sales_summary.to_csv("vendor_sales_summary",index=False)

# %%
import os
print(os.path.abspath("vendor_sales_summary.csv"))
# Out:
# C:\Users\rohit\vendor_sales_summary.csv

# %%
vendor_sales_summary.to_csv(r"C:\Users\rohit\vendor_sales_summary.csv",index=False)

# %%
file_path=r"C:\Users\rohit\vendor_sales_summary.csv"
print(os.path.exists(file_path))
print(os.path.getsize(file_path))
# Out:
# True
# 1985322

# %%
os.startfile(r"C:\Users\rohit\vendor_sales_summary.csv")
